# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mpl
import seaborn as sb
import warnings

# %%
pd.set_option('display.max_columns',None)

# %%
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\DATA\data.N\Credit Card Defaulter Prediction.csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL SEX   EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000   F  University  Married   24      2      2     -1     -1
# 1   2     120000   F  University   Single   26     -1      2      0      0
# 2   3      90000   F  University   Single   34      0      0      0      0
# 3   4      50000   F  University  Married   37      0      0      0      0
# 4   5      50000   M  University  Married   57     -1      0     -1      0
#
#    PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  BILL_AMT5  \
# 0     -2     -2       3913       3102        689          0          0
# 1      0      2       2682       1725       2682       3272       3455
# 2      0      0      29239      14027      13559      14331      14948
# 3      0      0      46990      48233      49291      28314      28959
# 4      0      0       8617       5670      35835      20940      19146
#
#    BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0          0         0       689         0         0         0         0
# 1       3261         0      1000      1000      1000         0      2000
# 2      15549      1518      1500      1000      1000      1000      5000
# 3      29547      2000      2019      1200      1100      1069      1000
# 4      19131      2000     36681     10000      9000       689       679
#
#   default
# 0        Y
# 1        Y
# 2        N
# 3        N
# 4        N

# %%
df.tail()
# Out:
#           ID  LIMIT_BAL SEX    EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000   M  High School  Married   39      0      0      0
# 29996  29997     150000   M  High School   Single   43     -1     -1     -1
# 29997  29998      30000   M   University   Single   37      4      3      2
# 29998  29999      80000   M  High School  Married   41      1     -1      0
# 29999  30000      50000   M   University  Married   46      0      0      0
#
#        PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# 29995      0      0      0     188948     192815     208365      88004
# 29996     -1      0      0       1683       1828       3502       8979
# 29997     -1      0      0       3565       3356       2758      20878
# 29998      0      0     -1      -1645      78379      76304      52774
# 29999      0      0      0      47929      48905      49764      36535
#
#        BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 29995      31237      15980      8500     20000      5003      3047      5000
# 29996       5190          0      1837      3526      8998       129         0
# 29997      20582      19357         0         0     22000      4200      2000
# 29998      11855      48944     85900      3409      1178      1926     52964
# 29999      32428      15313      2078      1800      1430      1000      1000
#
#        PAY_AMT6 default
# 29995      1000        N
# 29996         0        N
# 29997      3100        Y
# 29998      1804        Y
# 29999      1000        Y

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  object
#  3   EDUCATION  30000 non-null  object
#  4   MARRIAGE   30000 non-null  object
#  5   AGE        30000 non-null  int64
#  6   PAY_0      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
#  20  PAY_AMT3   30000 non-null  int64
#  21  PAY_AMT4   30000 non-null  int64
#  22  PAY_AMT5   30000 non-null  int64
#  23  PAY_AMT6   30000 non-null  int64
#  24  default    30000 non-null  object
# dtypes: int64(21), object(4)
# memory usage: 5.7+ MB

# %%
df.describe().transpose()
# Out:
#              count           mean            std       min       25%  \
# ID         30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# PAY_0      30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2      30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3      30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4      30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5      30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6      30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6  30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1   30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2   30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3   30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT4   30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT5   30000.0    4799.387633   15278.305679       0.0    252.50
# PAY_AMT6   30000.0    5215.502567   17777.465775       0.0    117.75
#
#                 50%        75%        max
# ID          15000.5   22500.25    30000.0
# LIMIT_BAL  140000.0  240000.00  1000000.0
# AGE            34.0      41.00       79.0
# PAY_0           0.0       0.00        8.0
# PAY_2           0.0       0.00        8.0
# PAY_3           0.0       0.00        8.0
# PAY_4           0.0       0.00        8.0
# PAY_5           0.0       0.00        8.0
# PAY_6           0.0       0.00        8.0
# BILL_AMT1   22381.5   67091.00   964511.0
# BILL_AMT2   21200.0   64006.25   983931.0
# BILL_AMT3   20088.5   60164.75  1664089.0
# BILL_AMT4   19052.0   54506.00   891586.0
# BILL_AMT5   18104.5   50190.50   927171.0
# BILL_AMT6   17071.0   49198.25   961664.0
# PAY_AMT1     2100.0    5006.00   873552.0
# PAY_AMT2     2009.0    5000.00  1684259.0
# PAY_AMT3     1800.0    4505.00   896040.0
# PAY_AMT4     1500.0    4013.25   621000.0
# PAY_AMT5     1500.0    4031.50   426529.0
# PAY_AMT6     1500.0    4000.00   528666.0

# %%
df = df.drop('ID',axis = 1)

# %%
df.isnull().sum()
# Out:
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# default      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 35

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.rename({'default ':'default'},axis = 1)

# %%
cat_var = []
for i in df.columns:
  if df[i].dtypes == 'O':
    cat_var.append(i)
cat_var
# Out:
# ['SEX', 'EDUCATION', 'MARRIAGE', 'default']

# %%
for j in cat_var:
  print('Column:- ',j)
  print(df[j].value_counts())
  print('')
# Out:
# Column:-  SEX
# F    18091
# M    11874
# Name: SEX, dtype: int64
#
# Column:-  EDUCATION
# University         14019
# Graduate school    10563
# High School         4915
# Unknown              331
# Others               123
# 0                     14
# Name: EDUCATION, dtype: int64
#
# Column:-  MARRIAGE
# Single     15945
# Married    13643
# Other        323
# 0             54
# Name: MARRIAGE, dtype: int64
#
# Column:-  default
# N    23335
# Y     6630
# Name: default, dtype: int64

# %%
df['EDUCATION'] = df['EDUCATION'].replace('0','Unknown')

# %%
df['EDUCATION'].value_counts()
# Out:
# University         14019
# Graduate school    10563
# High School         4915
# Unknown              345
# Others               123
# Name: EDUCATION, dtype: int64

# %%
df['MARRIAGE'] = df['MARRIAGE'].replace("0",'Other')

# %%
df['MARRIAGE'].value_counts()
# Out:
# Single     15945
# Married    13643
# Other        377
# Name: MARRIAGE, dtype: int64

# %%
sb.countplot(x = 'default',data = df)
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
sb.countplot(x = 'MARRIAGE',data = df,hue = 'default')
# Out:
# <AxesSubplot:xlabel='MARRIAGE', ylabel='count'>

# %%
sb.countplot(x = 'EDUCATION',data = df,hue = 'default')
# Out:
# <AxesSubplot:xlabel='EDUCATION', ylabel='count'>

# %%
num_var = []
for i in df.columns:
    if df[i].dtype == 'int64' or df[i].dtype == 'float':
        num_var.append(i)

# %%
num_var
# Out:
# ['LIMIT_BAL',
#  'AGE',
#  'PAY_0',
#  'PAY_2',
#  'PAY_3',
#  'PAY_4',
#  'PAY_5',
#  'PAY_6',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6']

# %%
for j in num_var:
    print('Column :- ',j)
    sb.boxplot(y = j,x = 'default',data = df)
    mpl.show()
    print('')
# Out:
# Column :-  LIMIT_BAL
# Column :-  AGE
# Column :-  PAY_0
# Column :-  PAY_2
# Column :-  PAY_3
# Column :-  PAY_4
# Column :-  PAY_5
# Column :-  PAY_6
# Column :-  BILL_AMT1
# Column :-  BILL_AMT2
# Column :-  BILL_AMT3
# Column :-  BILL_AMT4
# Column :-  BILL_AMT5
# Column :-  BILL_AMT6
# Column :-  PAY_AMT1
# Column :-  PAY_AMT2
# Column :-  PAY_AMT3
# Column :-  PAY_AMT4
# Column :-  PAY_AMT5
# Column :-  PAY_AMT6

# %%
for j in num_var:
    print('Column :- ',j)
    sb.distplot(df[j])
    mpl.show()
    print('')
# Out:
# Column :-  LIMIT_BAL
# Column :-  AGE
# Column :-  PAY_0
# Column :-  PAY_2
# Column :-  PAY_3
# Column :-  PAY_4
# Column :-  PAY_5
# Column :-  PAY_6
# Column :-  BILL_AMT1
# Column :-  BILL_AMT2
# Column :-  BILL_AMT3
# Column :-  BILL_AMT4
# Column :-  BILL_AMT5
# Column :-  BILL_AMT6
# Column :-  PAY_AMT1
# Column :-  PAY_AMT2
# Column :-  PAY_AMT3
# Column :-  PAY_AMT4
# Column :-  PAY_AMT5
# Column :-  PAY_AMT6

# %%
mpl.figure(figsize = (15,15))
sb.heatmap(df.corr(),annot = True,fmt = '.2f')
mpl.title('Correlation Plot')
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %%
from sklearn.model_selection import train_test_split
X = df.drop('default',axis = 1)
y = df['default']
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state = 42,test_size = 0.3)
X_train.shape,X_test.shape
# Out:
# ((20975, 23), (8990, 23))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
transformer = ColumnTransformer(transformers = [
    ('c1',OneHotEncoder(drop='first'),['SEX']),
    ('c2',OneHotEncoder(drop='first'),['MARRIAGE']),
    ('c3',OrdinalEncoder(categories = [['Unknown','Others','High School','Graduate school',
                                        'University']]),['EDUCATION']),
],remainder = 'passthrough')

# %%
X_train.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],
#       dtype='object')

# %%
df['MARRIAGE'].value_counts()
# Out:
# Single     15945
# Married    13643
# Other        377
# Name: MARRIAGE, dtype: int64

# %%
X_train_transform = transformer.fit_transform(X_train)
X_test_transform = transformer.transform(X_test)

# %%
X_train_transform.shape
# Out:
# (20975, 24)

# %%
X_train_new = pd.DataFrame(X_train_transform,columns = ['SEX','MAR_Other','MAR_Single','EDUCATION','LIMIT_BAL',
                                                        'AGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'])
X_test_new = pd.DataFrame(X_test_transform,columns = ['SEX','MAR_Other','MAR_Single','EDUCATION','LIMIT_BAL',
                                                        'AGE', 'PAY_0', 'PAY_2',
       'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'])

# %%
X_train_new.head(4)
# Out:
#    SEX  MAR_Other  MAR_Single  EDUCATION  LIMIT_BAL   AGE  PAY_0  PAY_2  \
# 0  1.0        0.0         0.0        4.0    80000.0  39.0    2.0    2.0
# 1  0.0        0.0         0.0        3.0    50000.0  25.0    0.0    0.0
# 2  1.0        0.0         0.0        4.0    20000.0  25.0    0.0    0.0
# 3  1.0        0.0         0.0        3.0   500000.0  41.0    0.0    0.0
#
#    PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# 0    2.0    2.0    2.0    2.0    51193.0    50954.0    55132.0    56629.0
# 1    0.0    0.0    0.0   -2.0    48294.0    48993.0    50702.0    49663.0
# 2    0.0    0.0    0.0    0.0    14447.0    15455.0    17562.0    17322.0
# 3    2.0    2.0   -1.0    2.0    62289.0    63485.0     2015.0     -121.0
#
#    BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# 0    57405.0    58742.0    1200.0    5000.0    3000.0    2300.0    2400.0
# 1        0.0        0.0    1805.0    2514.0    2475.0       0.0       0.0
# 2    17119.0    17350.0    1552.0    2659.0    1419.0     606.0     500.0
# 3      679.0      529.0    2608.0       0.0       0.0     800.0       0.0
#
#    PAY_AMT6
# 0       0.0
# 1       0.0
# 2    1000.0
# 3    1500.0

# %%
X_train_new.shape
# Out:
# (20975, 24)

# %%
le = LabelEncoder()
y_train_new = le.fit_transform(y_train)
y_test_new = le.fit_transform(y_test)

# %%
y_train_new = pd.DataFrame(y_train_new,columns = ['default'])
y_test_new = pd.DataFrame(y_test_new,columns = ['default'])

# %%
from imblearn.combine import SMOTETomek
samp = SMOTETomek()
X_train_samp,y_train_samp = samp.fit_resample(X_train_new,y_train_new)

# %%
y_train_samp.value_counts()
# Out:
# default
# 0          15865
# 1          15865
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train_scl = ss.fit_transform(X_train_samp)
X_test_scl = ss.transform(X_test_new)

# %%
X_train_scl
# Out:
# array([[ 1.27969556, -0.12338897, -1.11177985, ..., -0.13572252,
#         -0.12712776, -0.29026962],
#        [-0.88245372, -0.12338897, -1.11177985, ..., -0.3107924 ,
#         -0.30995507, -0.29026962],
#        [ 1.27969556, -0.12338897, -1.11177985, ..., -0.26466529,
#         -0.27186605, -0.22439867],
#        ...,
#        [ 1.27969556,  7.07862922, -0.61695672, ...,  0.20149991,
#          0.59155062,  0.0937776 ],
#        [ 0.10511158, -0.12338897, -1.11177985, ..., -0.23467506,
#         -0.26857147, -0.27823495],
#        [ 0.18549274, -0.12338897,  1.01792984, ..., -0.3107924 ,
#         -0.30995507, -0.29026962]])

# %% [markdown]
# ## **PCA**

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
X_train1 = pca.fit_transform(X_train_scl)
X_test1 = pca.transform(X_test_scl)

# %%
X_train2 = pd.DataFrame(X_train1,columns = ['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10',])
X_test2 = pd.DataFrame(X_test1,columns = ['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10',])

# %%
X_train2.head()
# Out:
#          P1        P2        P3        P4        P5        P6        P7  \
# 0  2.027334 -3.328770  1.033913  0.431974 -0.239748  1.468549  0.426890
# 1 -0.944710 -0.006573 -0.149221 -0.719167  0.783766 -0.592786 -0.362654
# 2 -1.071167 -0.909103 -0.241723 -0.163705 -0.229653  1.158715  0.931056
# 3  0.032901 -0.862492  1.692894  0.504963 -0.899327  0.917795 -0.504200
# 4  1.933310  3.913004  0.367416  5.687682  0.737202 -0.799341 -0.714839
#
#          P8        P9       P10
# 0  0.152581 -0.079083  0.294135
# 1  0.211959 -0.181538  0.034179
# 2 -0.002912 -0.270209  0.309840
# 3 -0.266779 -0.179971  0.056649
# 4 -2.179074  1.011013  4.701656

# %%
mpl.figure(figsize = (10,10))
sb.heatmap(X_train2.corr(),annot = True,fmt = '.4f')
mpl.title('Correlation Plot')
# Out:
# Text(0.5, 1.0, 'Correlation Plot')

# %% [markdown]
# ## **LOGISTIC REGRESSION**

# %%
from sklearn.linear_model import LogisticRegression
lor = LogisticRegression()
lor_model = lor.fit(X_train_scl,y_train_samp)
lor_model
# Out:
# LogisticRegression()

# %%
lor_y_pred = lor_model.predict(X_test_scl)
lor_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test_new,lor_y_pred)
# Out:
# 0.7017797552836484

# %%
def CM(actual,pred):
  cm = sb.heatmap(confusion_matrix(actual,pred),annot = True,fmt = '.2f',xticklabels=['Yes','No'],yticklabels=['Yes','No'])
  mpl.xlabel("Predicted")
  mpl.ylabel("Actual")
  mpl.title('Confusion Matrix')
  mpl.show()
  return cm

# %%
CM(y_test_new,lor_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ## **LOGISTIC REGRESSION WITH SGD**

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(penalty="l1")
sgd_model = sgd.fit(X_train_scl,y_train_samp)
sgd_model
# Out:
# SGDClassifier(penalty='l1')

# %%
sgd_y_pred = sgd_model.predict(X_test_scl)
sgd_y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,sgd_y_pred)
# Out:
# 0.7275862068965517

# %%
CM(y_test_new,sgd_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ## **DECISION TREE**

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(criterion = 'gini',max_depth=5,min_samples_split=20)
dt_model = dt.fit(X_train_scl,y_train_samp)
dt_model
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=20)

# %%
dt_y_pred = dt_model.predict(X_test_scl)
dt_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,dt_y_pred)
# Out:
# 0.8042269187986651

# %%
# from sklearn.model_selection import RandomizedSearchCV
# dt_param = [{'criterion':['gini','entropy'],'min_samples_split':range(10,30),'max_depth':range(3,10)}]
# rs = RandomizedSearchCV(DecisionTreeClassifier(),dt_param,cv = 10,scoring = 'accuracy')
# rs.fit(X_train2,y_train_samp)

# %%
# rs.best_params_

# %%
# rs.best_score_

# %% [markdown]
# # **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(criterion = 'entropy',max_depth = 7 , min_samples_split = 20,n_estimators = 200)
rf_model = rf.fit(X_train_scl,y_train_samp)
rf_model
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=7, min_samples_split=20,
#                        n_estimators=200)

# %%
rf_y_pred = rf_model.predict(X_test_scl)
rf_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,rf_y_pred)
# Out:
# 0.8056729699666296

# %%
CM(y_test_new,rf_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ## **ADABOOST CLASSIFIER**

# %%
from sklearn.ensemble import AdaBoostClassifier
abc = AdaBoostClassifier(n_estimators=100)
abc_model = abc.fit(X_train_scl,y_train_samp)
abc_model
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
abc_y_pred = abc_model.predict(X_test_scl)
abc_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,abc_y_pred)
# Out:
# 0.8166852057842047

# %%
CM(y_test_new,abc_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ## **GRADIENTBOOST CLASSIFIER**

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc_model = gbc.fit(X_train_scl,y_train_samp)
gbc_model
# Out:
# GradientBoostingClassifier()

# %%
gbc_y_pred = gbc_model.predict(X_test_scl)
gbc_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,gbc_y_pred)
# Out:
# 0.8200222469410456

# %%
CM(y_test_new,gbc_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>

# %% [markdown]
# ## **XGBOOST**

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb_model = xgb.fit(X_train_scl,y_train_samp)
xgb_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgb_y_pred = xgb_model.predict(X_test_scl)
xgb_y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test_new,xgb_y_pred)
# Out:
# 0.810567296996663

# %%
CM(y_test_new,xgb_y_pred)
# Out:
# <AxesSubplot:title={'center':'Confusion Matrix'}, xlabel='Predicted', ylabel='Actual'>
